# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('wells_info.csv', index_col=0) # sep = '', delimiter = '', nrows = 10, header = None

# %%
df['CompletionDate'] = pd.to_datetime(df['CompletionDate'])
df['FirstProductionDate'] = pd.to_datetime(df['FirstProductionDate'])

# %%
df['ProductionDuration_months'] = 0
for i in range(df.shape[0]):
    df.iloc[i,16] = (df.iloc[i,2] - df.iloc[i,3]).days // 30
df
# Out:
#                 PermitDate    SpudDate CompletionDate FirstProductionDate  \
# API
# 5005072170100   2014-05-06  2014-05-06     2014-12-02          2014-11-01
# 5123377130000   2013-07-21  2013-10-06     2014-02-26          2014-02-01
# 5123379280000   2013-09-08  2013-09-25     2014-09-07          2013-11-01
# 5123379400000   2013-09-11  2014-12-05     2015-03-31          2015-03-01
# 5123385820100   2014-01-07  2014-01-13     2014-04-23          2014-04-01
# 5123390320000   2014-02-27  2014-06-20     2014-10-30          2014-10-01
# 5123390440000   2014-02-28  2014-04-26     2014-08-16          2014-08-01
# 5123392690000   2014-04-14  2015-03-20     2015-08-03          2015-07-01
# 5123399750000   2014-08-09  2014-11-14     2015-04-16          2015-04-01
# 5123402600000   2014-09-22  2015-06-16     2015-09-13          2015-09-01
# 5123409020000   2014-12-23  2015-02-07     2015-09-07          2015-09-01
# 5123410480000   2015-01-21  2015-03-16     2015-04-23          2015-04-01
# ...

# %%
df['ProductionDuration_months'] = (df['CompletionDate'] - df['FirstProductionDate']).dt.days // 30
df
# Out:
#                 PermitDate    SpudDate CompletionDate FirstProductionDate  \
# API
# 5005072170100   2014-05-06  2014-05-06     2014-12-02          2014-11-01
# 5123377130000   2013-07-21  2013-10-06     2014-02-26          2014-02-01
# 5123379280000   2013-09-08  2013-09-25     2014-09-07          2013-11-01
# 5123379400000   2013-09-11  2014-12-05     2015-03-31          2015-03-01
# 5123385820100   2014-01-07  2014-01-13     2014-04-23          2014-04-01
# 5123390320000   2014-02-27  2014-06-20     2014-10-30          2014-10-01
# 5123390440000   2014-02-28  2014-04-26     2014-08-16          2014-08-01
# 5123392690000   2014-04-14  2015-03-20     2015-08-03          2015-07-01
# 5123399750000   2014-08-09  2014-11-14     2015-04-16          2015-04-01
# 5123402600000   2014-09-22  2015-06-16     2015-09-13          2015-09-01
# 5123409020000   2014-12-23  2015-02-07     2015-09-07          2015-09-01
# 5123410480000   2015-01-21  2015-03-16     2015-04-23          2015-04-01
# ...
